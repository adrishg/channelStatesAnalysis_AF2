# %%
import os
import numpy as np
import shutil
from pathlib import Path

# Function to extract Cα coordinates from a PDB file
def extract_ca_coordinates(pdb_file, chainID):
    ca_coords = []
    with open(pdb_file, 'r') as file:
        for line in file:
            if line.startswith("ATOM") and " CA " in line and line[21] == chainID:
                x = float(line[30:38].strip())
                y = float(line[38:46].strip())
                z = float(line[46:54].strip())
                ca_coords.append([x, y, z])
    return np.array(ca_coords)

# Function to calculate RMSD between two sets of coordinates
def calculate_rmsd(coords1, coords2):
    diff = coords1 - coords2
    return np.sqrt(np.sum(diff**2) / len(coords1))

# Function to superpose structures using the Kabsch algorithm
def superpose_structures(ref_coords, target_coords):
    ref_center = np.mean(ref_coords, axis=0)
    target_center = np.mean(target_coords, axis=0)

    ref_centered = ref_coords - ref_center
    target_centered = target_coords - target_center

    H = np.dot(target_centered.T, ref_centered)
    U, S, Vt = np.linalg.svd(H)
    R = np.dot(Vt.T, U.T)

    if np.linalg.det(R) < 0:
        Vt[-1, :] *= -1
        R = np.dot(Vt.T, U.T)

    aligned_coords = np.dot(target_centered, R) + ref_center
    return aligned_coords

# Function to process a model-seed combination and identify convergence
def process_model_seed(folder, model_number, model_seed, chainID='A', rmsd_threshold=7):
    # Ensure the output folder exists
    converged_folder = Path(folder) / "rmsf_converged"
    converged_folder.mkdir(exist_ok=True)

    # Collect all PDB files for this model and seed
    pdb_files = sorted([
        f for f in os.listdir(folder)
        if f.endswith(".pdb") and f"model_{model_number}_ptm_" in f and f"seed{model_seed}" in f
    ])

    print(f"Processing Model {model_number}, Seed {model_seed}: Found {len(pdb_files)} PDB files.")

    if len(pdb_files) < 2:
        print(f"Not enough recycles for model {model_number}, seed {model_seed}.")
        return

    # Iterate through the recycles and calculate RMSD
    for i in range(len(pdb_files) - 1):
        file1 = Path(folder) / pdb_files[i]
        file2 = Path(folder) / pdb_files[i + 1]

        coords1 = extract_ca_coordinates(file1, chainID)
        coords2 = extract_ca_coordinates(file2, chainID)

        if coords1.size == 0 or coords2.size == 0:
            print(f"Skipping files {pdb_files[i]} or {pdb_files[i + 1]} due to missing Cα coordinates.")
            continue

        aligned_coords2 = superpose_structures(coords1, coords2)
        rmsd = calculate_rmsd(coords1, aligned_coords2)

        # Print the RMSD for this pair of recycles
        print(f"Model {model_number}, Seed {model_seed}, Recycle {i} to {i + 1}: RMSD = {rmsd:.2f} Å")

        # If RMSD is below the threshold, copy the file to the converged folder
        if rmsd <= rmsd_threshold:
            print(f"Convergence detected: RMSD = {rmsd:.2f} Å. Copying files.")
            shutil.copy(file1, converged_folder)
            shutil.copy(file2, converged_folder)
            break

# Function to process all models and seeds in a folder
def process_all_models(folder, rmsd_threshold=7, chainID='A'):
    print(f"Scanning folder: {folder}")
    models_and_seeds = {}
    for filename in os.listdir(folder):
        if filename.endswith(".pdb"):
            parts = filename.split("_")
            try:
                model_number = parts[1]  # Extract the model number
                seed_number = parts[4][4:].split(".")[0]  # Extract the seed number
                if (model_number, seed_number) not in models_and_seeds:
                    models_and_seeds[(model_number, seed_number)] = []
                models_and_seeds[(model_number, seed_number)].append(filename)
            except IndexError:
                print(f"Skipping file {filename}: unexpected filename format.")
                continue

    # Process each model and seed combination
    for (model_number, seed_number), files in models_and_seeds.items():
        process_model_seed(folder, model_number, seed_number, chainID, rmsd_threshold)

# %%
# Example usage
if __name__ == "__main__":
    folder_path = '/Users/adrianahernandezgonzalez/LabNotebook/11-24/states/partialAlphaCaV12HS8HLPlocalrun_b3702_8_16_10/pdb/'  # Replace with the path to your folder containing PDB files
    rmsd_cutoff = 12  # Default RMSD cutoff for convergence
    process_all_models(folder_path, rmsd_threshold=rmsd_cutoff)
# Out:
# Scanning folder: /Users/adrianahernandezgonzalez/LabNotebook/11-24/states/partialAlphaCaV12HS8HLPlocalrun_b3702_8_16_10/pdb/
# Processing Model 2, Seed 1: Found 13 PDB files.
# Model 2, Seed 1, Recycle 0 to 1: RMSD = 71.61 Å
# Model 2, Seed 1, Recycle 1 to 2: RMSD = 21.49 Å
# Model 2, Seed 1, Recycle 2 to 3: RMSD = 24.92 Å
# Model 2, Seed 1, Recycle 3 to 4: RMSD = 59.72 Å
# Model 2, Seed 1, Recycle 4 to 5: RMSD = 30.42 Å
# Model 2, Seed 1, Recycle 5 to 6: RMSD = 18.46 Å
# Model 2, Seed 1, Recycle 6 to 7: RMSD = 8.34 Å
# Convergence detected: RMSD = 8.34 Å. Copying files.
# Processing Model 3, Seed 7: Found 13 PDB files.
# Model 3, Seed 7, Recycle 0 to 1: RMSD = 62.43 Å
# Model 3, Seed 7, Recycle 1 to 2: RMSD = 57.96 Å
# Model 3, Seed 7, Recycle 2 to 3: RMSD = 62.14 Å
# Model 3, Seed 7, Recycle 3 to 4: RMSD = 55.48 Å
# Model 3, Seed 7, Recycle 4 to 5: RMSD = 59.30 Å
# Model 3, Seed 7, Recycle 5 to 6: RMSD = 54.70 Å
# Model 3, Seed 7, Recycle 6 to 7: RMSD = 54.95 Å
# Model 3, Seed 7, Recycle 7 to 8: RMSD = 62.73 Å
# Model 3, Seed 7, Recycle 8 to 9: RMSD = 63.88 Å
# Model 3, Seed 7, Recycle 9 to 10: RMSD = 57.35 Å
# Model 3, Seed 7, Recycle 10 to 11: RMSD = 54.08 Å
# Model 3, Seed 7, Recycle 11 to 12: RMSD = 63.45 Å
# Processing Model 4, Seed 6: Found 13 PDB files.
# Model 4, Seed 6, Recycle 0 to 1: RMSD = 35.39 Å
# Model 4, Seed 6, Recycle 1 to 2: RMSD = 57.29 Å
# Model 4, Seed 6, Recycle 2 to 3: RMSD = 57.86 Å
# Model 4, Seed 6, Recycle 3 to 4: RMSD = 65.83 Å
# Model 4, Seed 6, Recycle 4 to 5: RMSD = 68.60 Å
# Model 4, Seed 6, Recycle 5 to 6: RMSD = 69.16 Å
# Model 4, Seed 6, Recycle 6 to 7: RMSD = 61.04 Å
# Model 4, Seed 6, Recycle 7 to 8: RMSD = 66.51 Å
# Model 4, Seed 6, Recycle 8 to 9: RMSD = 65.61 Å
# Model 4, Seed 6, Recycle 9 to 10: RMSD = 59.16 Å
# Model 4, Seed 6, Recycle 10 to 11: RMSD = 63.89 Å
# Model 4, Seed 6, Recycle 11 to 12: RMSD = 63.35 Å
# Processing Model 5, Seed 0: Found 13 PDB files.
# Model 5, Seed 0, Recycle 0 to 1: RMSD = 56.90 Å
# Model 5, Seed 0, Recycle 1 to 2: RMSD = 37.85 Å
# Model 5, Seed 0, Recycle 2 to 3: RMSD = 24.22 Å
# Model 5, Seed 0, Recycle 3 to 4: RMSD = 56.71 Å
# Model 5, Seed 0, Recycle 4 to 5: RMSD = 49.06 Å
# Model 5, Seed 0, Recycle 5 to 6: RMSD = 12.45 Å
# Model 5, Seed 0, Recycle 6 to 7: RMSD = 24.58 Å
# Model 5, Seed 0, Recycle 7 to 8: RMSD = 4.45 Å
# Convergence detected: RMSD = 4.45 Å. Copying files.
# Processing Model 5, Seed 2: Found 13 PDB files.
# Model 5, Seed 2, Recycle 0 to 1: RMSD = 51.07 Å
# Model 5, Seed 2, Recycle 1 to 2: RMSD = 29.38 Å
# Model 5, Seed 2, Recycle 2 to 3: RMSD = 6.19 Å
# Convergence detected: RMSD = 6.19 Å. Copying files.
# Processing Model 4, Seed 4: Found 13 PDB files.
# Model 4, Seed 4, Recycle 0 to 1: RMSD = 53.09 Å
# Model 4, Seed 4, Recycle 1 to 2: RMSD = 61.97 Å
# Model 4, Seed 4, Recycle 2 to 3: RMSD = 54.57 Å
# Model 4, Seed 4, Recycle 3 to 4: RMSD = 57.56 Å
# Model 4, Seed 4, Recycle 4 to 5: RMSD = 65.54 Å
# Model 4, Seed 4, Recycle 5 to 6: RMSD = 66.27 Å
# Model 4, Seed 4, Recycle 6 to 7: RMSD = 60.69 Å
# Model 4, Seed 4, Recycle 7 to 8: RMSD = 58.68 Å
# Model 4, Seed 4, Recycle 8 to 9: RMSD = 65.63 Å
# Model 4, Seed 4, Recycle 9 to 10: RMSD = 63.56 Å
# Model 4, Seed 4, Recycle 10 to 11: RMSD = 54.35 Å
# Model 4, Seed 4, Recycle 11 to 12: RMSD = 62.80 Å
# Processing Model 1, Seed 3: Found 13 PDB files.
# Model 1, Seed 3, Recycle 0 to 1: RMSD = 47.72 Å
# Model 1, Seed 3, Recycle 1 to 2: RMSD = 34.14 Å
# Model 1, Seed 3, Recycle 2 to 3: RMSD = 11.76 Å
# Model 1, Seed 3, Recycle 3 to 4: RMSD = 38.82 Å
# Model 1, Seed 3, Recycle 4 to 5: RMSD = 41.42 Å
# Model 1, Seed 3, Recycle 5 to 6: RMSD = 25.11 Å
# Model 1, Seed 3, Recycle 6 to 7: RMSD = 33.86 Å
# Model 1, Seed 3, Recycle 7 to 8: RMSD = 24.88 Å
# Model 1, Seed 3, Recycle 8 to 9: RMSD = 22.42 Å
# Model 1, Seed 3, Recycle 9 to 10: RMSD = 17.18 Å
# Model 1, Seed 3, Recycle 10 to 11: RMSD = 20.09 Å
# Model 1, Seed 3, Recycle 11 to 12: RMSD = 32.33 Å
# Processing Model 3, Seed 4: Found 13 PDB files.
# Model 3, Seed 4, Recycle 0 to 1: RMSD = 61.65 Å
# Model 3, Seed 4, Recycle 1 to 2: RMSD = 62.23 Å
# Model 3, Seed 4, Recycle 2 to 3: RMSD = 61.47 Å
# Model 3, Seed 4, Recycle 3 to 4: RMSD = 59.89 Å
# Model 3, Seed 4, Recycle 4 to 5: RMSD = 60.65 Å
# Model 3, Seed 4, Recycle 5 to 6: RMSD = 63.35 Å
# Model 3, Seed 4, Recycle 6 to 7: RMSD = 63.30 Å
# Model 3, Seed 4, Recycle 7 to 8: RMSD = 59.41 Å
# Model 3, Seed 4, Recycle 8 to 9: RMSD = 63.83 Å
# Model 3, Seed 4, Recycle 9 to 10: RMSD = 63.12 Å
# Model 3, Seed 4, Recycle 10 to 11: RMSD = 60.16 Å
# Model 3, Seed 4, Recycle 11 to 12: RMSD = 57.16 Å
# Processing Model 5, Seed 8: Found 13 PDB files.
# Model 5, Seed 8, Recycle 0 to 1: RMSD = 56.35 Å
# Model 5, Seed 8, Recycle 1 to 2: RMSD = 32.79 Å
# Model 5, Seed 8, Recycle 2 to 3: RMSD = 13.87 Å
# Model 5, Seed 8, Recycle 3 to 4: RMSD = 69.01 Å
# Model 5, Seed 8, Recycle 4 to 5: RMSD = 35.24 Å
# Model 5, Seed 8, Recycle 5 to 6: RMSD = 22.25 Å
# Model 5, Seed 8, Recycle 6 to 7: RMSD = 29.93 Å
# Model 5, Seed 8, Recycle 7 to 8: RMSD = 10.40 Å
# Model 5, Seed 8, Recycle 8 to 9: RMSD = 41.17 Å
# Model 5, Seed 8, Recycle 9 to 10: RMSD = 18.82 Å
# Model 5, Seed 8, Recycle 10 to 11: RMSD = 25.84 Å
# Model 5, Seed 8, Recycle 11 to 12: RMSD = 16.20 Å
# Processing Model 2, Seed 9: Found 13 PDB files.
# Model 2, Seed 9, Recycle 0 to 1: RMSD = 55.81 Å
# Model 2, Seed 9, Recycle 1 to 2: RMSD = 23.47 Å
# Model 2, Seed 9, Recycle 2 to 3: RMSD = 11.19 Å
# Model 2, Seed 9, Recycle 3 to 4: RMSD = 44.09 Å
# Model 2, Seed 9, Recycle 4 to 5: RMSD = 19.73 Å
# Model 2, Seed 9, Recycle 5 to 6: RMSD = 26.63 Å
# Model 2, Seed 9, Recycle 6 to 7: RMSD = 39.61 Å
# Model 2, Seed 9, Recycle 7 to 8: RMSD = 21.68 Å
# Model 2, Seed 9, Recycle 8 to 9: RMSD = 16.99 Å
# Model 2, Seed 9, Recycle 9 to 10: RMSD = 20.28 Å
# Model 2, Seed 9, Recycle 10 to 11: RMSD = 6.77 Å
# Convergence detected: RMSD = 6.77 Å. Copying files.
# Processing Model 1, Seed 7: Found 13 PDB files.
# Model 1, Seed 7, Recycle 0 to 1: RMSD = 68.81 Å
# Model 1, Seed 7, Recycle 1 to 2: RMSD = 18.76 Å
# Model 1, Seed 7, Recycle 2 to 3: RMSD = 25.59 Å
# Model 1, Seed 7, Recycle 3 to 4: RMSD = 55.11 Å
# Model 1, Seed 7, Recycle 4 to 5: RMSD = 24.96 Å
# Model 1, Seed 7, Recycle 5 to 6: RMSD = 25.28 Å
# Model 1, Seed 7, Recycle 6 to 7: RMSD = 5.68 Å
# Convergence detected: RMSD = 5.68 Å. Copying files.
# Processing Model 2, Seed 5: Found 13 PDB files.
# Model 2, Seed 5, Recycle 0 to 1: RMSD = 59.46 Å
# Model 2, Seed 5, Recycle 1 to 2: RMSD = 33.66 Å
# Model 2, Seed 5, Recycle 2 to 3: RMSD = 17.74 Å
# Model 2, Seed 5, Recycle 3 to 4: RMSD = 60.79 Å
# Model 2, Seed 5, Recycle 4 to 5: RMSD = 36.09 Å
# Model 2, Seed 5, Recycle 5 to 6: RMSD = 13.11 Å
# Model 2, Seed 5, Recycle 6 to 7: RMSD = 12.17 Å
# Model 2, Seed 5, Recycle 7 to 8: RMSD = 16.87 Å
# Model 2, Seed 5, Recycle 8 to 9: RMSD = 16.49 Å
# Model 2, Seed 5, Recycle 9 to 10: RMSD = 9.06 Å
# Convergence detected: RMSD = 9.06 Å. Copying files.
# Processing Model 1, Seed 4: Found 13 PDB files.
# Model 1, Seed 4, Recycle 0 to 1: RMSD = 50.68 Å
# Model 1, Seed 4, Recycle 1 to 2: RMSD = 24.53 Å
# Model 1, Seed 4, Recycle 2 to 3: RMSD = 5.06 Å
# Convergence detected: RMSD = 5.06 Å. Copying files.
# Processing Model 5, Seed 7: Found 13 PDB files.
# Model 5, Seed 7, Recycle 0 to 1: RMSD = 40.42 Å
# Model 5, Seed 7, Recycle 1 to 2: RMSD = 13.79 Å
# Model 5, Seed 7, Recycle 2 to 3: RMSD = 30.06 Å
# Model 5, Seed 7, Recycle 3 to 4: RMSD = 50.17 Å
# Model 5, Seed 7, Recycle 4 to 5: RMSD = 22.93 Å
# Model 5, Seed 7, Recycle 5 to 6: RMSD = 25.83 Å
# Model 5, Seed 7, Recycle 6 to 7: RMSD = 5.56 Å
# Convergence detected: RMSD = 5.56 Å. Copying files.
# Processing Model 4, Seed 1: Found 13 PDB files.
# Model 4, Seed 1, Recycle 0 to 1: RMSD = 49.36 Å
# Model 4, Seed 1, Recycle 1 to 2: RMSD = 60.59 Å
# Model 4, Seed 1, Recycle 2 to 3: RMSD = 63.05 Å
# Model 4, Seed 1, Recycle 3 to 4: RMSD = 48.80 Å
# Model 4, Seed 1, Recycle 4 to 5: RMSD = 46.96 Å
# Model 4, Seed 1, Recycle 5 to 6: RMSD = 62.09 Å
# Model 4, Seed 1, Recycle 6 to 7: RMSD = 58.46 Å
# Model 4, Seed 1, Recycle 7 to 8: RMSD = 68.81 Å
# Model 4, Seed 1, Recycle 8 to 9: RMSD = 67.42 Å
# Model 4, Seed 1, Recycle 9 to 10: RMSD = 53.01 Å
# Model 4, Seed 1, Recycle 10 to 11: RMSD = 66.50 Å
# Model 4, Seed 1, Recycle 11 to 12: RMSD = 65.56 Å
# Processing Model 3, Seed 0: Found 13 PDB files.
# Model 3, Seed 0, Recycle 0 to 1: RMSD = 50.14 Å
# Model 3, Seed 0, Recycle 1 to 2: RMSD = 59.94 Å
# Model 3, Seed 0, Recycle 2 to 3: RMSD = 57.99 Å
# Model 3, Seed 0, Recycle 3 to 4: RMSD = 58.10 Å
# Model 3, Seed 0, Recycle 4 to 5: RMSD = 62.91 Å
# Model 3, Seed 0, Recycle 5 to 6: RMSD = 64.07 Å
# Model 3, Seed 0, Recycle 6 to 7: RMSD = 62.00 Å
# Model 3, Seed 0, Recycle 7 to 8: RMSD = 60.79 Å
# Model 3, Seed 0, Recycle 8 to 9: RMSD = 60.81 Å
# Model 3, Seed 0, Recycle 9 to 10: RMSD = 56.78 Å
# Model 3, Seed 0, Recycle 10 to 11: RMSD = 59.19 Å
# Model 3, Seed 0, Recycle 11 to 12: RMSD = 61.38 Å
# Processing Model 2, Seed 6: Found 13 PDB files.
# Model 2, Seed 6, Recycle 0 to 1: RMSD = 53.94 Å
# Model 2, Seed 6, Recycle 1 to 2: RMSD = 20.70 Å
# Model 2, Seed 6, Recycle 2 to 3: RMSD = 14.49 Å
# Model 2, Seed 6, Recycle 3 to 4: RMSD = 58.49 Å
# Model 2, Seed 6, Recycle 4 to 5: RMSD = 23.94 Å
# Model 2, Seed 6, Recycle 5 to 6: RMSD = 14.94 Å
# Model 2, Seed 6, Recycle 6 to 7: RMSD = 14.54 Å
# Model 2, Seed 6, Recycle 7 to 8: RMSD = 21.02 Å
# Model 2, Seed 6, Recycle 8 to 9: RMSD = 12.18 Å
# Model 2, Seed 6, Recycle 9 to 10: RMSD = 11.57 Å
# Model 2, Seed 6, Recycle 10 to 11: RMSD = 11.75 Å
# Model 2, Seed 6, Recycle 11 to 12: RMSD = 12.80 Å
# Processing Model 3, Seed 8: Found 13 PDB files.
# Model 3, Seed 8, Recycle 0 to 1: RMSD = 50.47 Å
# Model 3, Seed 8, Recycle 1 to 2: RMSD = 49.94 Å
# Model 3, Seed 8, Recycle 2 to 3: RMSD = 62.57 Å
# Model 3, Seed 8, Recycle 3 to 4: RMSD = 46.98 Å
# Model 3, Seed 8, Recycle 4 to 5: RMSD = 56.42 Å
# Model 3, Seed 8, Recycle 5 to 6: RMSD = 62.27 Å
# Model 3, Seed 8, Recycle 6 to 7: RMSD = 50.76 Å
# Model 3, Seed 8, Recycle 7 to 8: RMSD = 59.59 Å
# Model 3, Seed 8, Recycle 8 to 9: RMSD = 62.24 Å
# Model 3, Seed 8, Recycle 9 to 10: RMSD = 57.41 Å
# Model 3, Seed 8, Recycle 10 to 11: RMSD = 56.48 Å
# Model 3, Seed 8, Recycle 11 to 12: RMSD = 62.60 Å
# Processing Model 4, Seed 9: Found 13 PDB files.
# Model 4, Seed 9, Recycle 0 to 1: RMSD = 40.27 Å
# Model 4, Seed 9, Recycle 1 to 2: RMSD = 60.06 Å
# Model 4, Seed 9, Recycle 2 to 3: RMSD = 61.98 Å
# Model 4, Seed 9, Recycle 3 to 4: RMSD = 54.77 Å
# Model 4, Seed 9, Recycle 4 to 5: RMSD = 66.97 Å
# Model 4, Seed 9, Recycle 5 to 6: RMSD = 47.63 Å
# Model 4, Seed 9, Recycle 6 to 7: RMSD = 64.42 Å
# Model 4, Seed 9, Recycle 7 to 8: RMSD = 61.02 Å
# Model 4, Seed 9, Recycle 8 to 9: RMSD = 51.73 Å
# Model 4, Seed 9, Recycle 9 to 10: RMSD = 63.62 Å
# Model 4, Seed 9, Recycle 10 to 11: RMSD = 59.74 Å
# Model 4, Seed 9, Recycle 11 to 12: RMSD = 62.37 Å
# Processing Model 4, Seed 8: Found 13 PDB files.
# Model 4, Seed 8, Recycle 0 to 1: RMSD = 61.00 Å
# Model 4, Seed 8, Recycle 1 to 2: RMSD = 61.38 Å
# Model 4, Seed 8, Recycle 2 to 3: RMSD = 53.95 Å
# Model 4, Seed 8, Recycle 3 to 4: RMSD = 47.87 Å
# Model 4, Seed 8, Recycle 4 to 5: RMSD = 71.79 Å
# Model 4, Seed 8, Recycle 5 to 6: RMSD = 68.08 Å
# Model 4, Seed 8, Recycle 6 to 7: RMSD = 64.02 Å
# Model 4, Seed 8, Recycle 7 to 8: RMSD = 64.83 Å
# Model 4, Seed 8, Recycle 8 to 9: RMSD = 53.85 Å
# Model 4, Seed 8, Recycle 9 to 10: RMSD = 58.24 Å
# Model 4, Seed 8, Recycle 10 to 11: RMSD = 64.80 Å
# Model 4, Seed 8, Recycle 11 to 12: RMSD = 62.48 Å
# Processing Model 3, Seed 9: Found 13 PDB files.
# Model 3, Seed 9, Recycle 0 to 1: RMSD = 41.18 Å
# Model 3, Seed 9, Recycle 1 to 2: RMSD = 61.58 Å
# Model 3, Seed 9, Recycle 2 to 3: RMSD = 61.03 Å
# Model 3, Seed 9, Recycle 3 to 4: RMSD = 49.02 Å
# Model 3, Seed 9, Recycle 4 to 5: RMSD = 59.52 Å
# Model 3, Seed 9, Recycle 5 to 6: RMSD = 60.11 Å
# Model 3, Seed 9, Recycle 6 to 7: RMSD = 63.50 Å
# Model 3, Seed 9, Recycle 7 to 8: RMSD = 64.88 Å
# Model 3, Seed 9, Recycle 8 to 9: RMSD = 57.91 Å
# Model 3, Seed 9, Recycle 9 to 10: RMSD = 55.59 Å
# Model 3, Seed 9, Recycle 10 to 11: RMSD = 61.83 Å
# Model 3, Seed 9, Recycle 11 to 12: RMSD = 56.77 Å
# Processing Model 2, Seed 0: Found 13 PDB files.
# Model 2, Seed 0, Recycle 0 to 1: RMSD = 59.35 Å
# Model 2, Seed 0, Recycle 1 to 2: RMSD = 7.54 Å
# Convergence detected: RMSD = 7.54 Å. Copying files.
# Processing Model 3, Seed 6: Found 13 PDB files.
# Model 3, Seed 6, Recycle 0 to 1: RMSD = 58.79 Å
# Model 3, Seed 6, Recycle 1 to 2: RMSD = 55.33 Å
# Model 3, Seed 6, Recycle 2 to 3: RMSD = 61.96 Å
# Model 3, Seed 6, Recycle 3 to 4: RMSD = 51.62 Å
# Model 3, Seed 6, Recycle 4 to 5: RMSD = 58.21 Å
# Model 3, Seed 6, Recycle 5 to 6: RMSD = 56.45 Å
# Model 3, Seed 6, Recycle 6 to 7: RMSD = 62.04 Å
# Model 3, Seed 6, Recycle 7 to 8: RMSD = 61.70 Å
# Model 3, Seed 6, Recycle 8 to 9: RMSD = 60.02 Å
# Model 3, Seed 6, Recycle 9 to 10: RMSD = 58.42 Å
# Model 3, Seed 6, Recycle 10 to 11: RMSD = 61.06 Å
# Model 3, Seed 6, Recycle 11 to 12: RMSD = 61.59 Å
# Processing Model 3, Seed 1: Found 13 PDB files.
# Model 3, Seed 1, Recycle 0 to 1: RMSD = 52.23 Å
# Model 3, Seed 1, Recycle 1 to 2: RMSD = 58.11 Å
# Model 3, Seed 1, Recycle 2 to 3: RMSD = 61.37 Å
# Model 3, Seed 1, Recycle 3 to 4: RMSD = 51.66 Å
# Model 3, Seed 1, Recycle 4 to 5: RMSD = 61.92 Å
# Model 3, Seed 1, Recycle 5 to 6: RMSD = 63.28 Å
# Model 3, Seed 1, Recycle 6 to 7: RMSD = 62.58 Å
# Model 3, Seed 1, Recycle 7 to 8: RMSD = 63.55 Å
# Model 3, Seed 1, Recycle 8 to 9: RMSD = 62.22 Å
# Model 3, Seed 1, Recycle 9 to 10: RMSD = 50.40 Å
# Model 3, Seed 1, Recycle 10 to 11: RMSD = 60.48 Å
# Model 3, Seed 1, Recycle 11 to 12: RMSD = 62.44 Å
# Processing Model 2, Seed 7: Found 13 PDB files.
# Model 2, Seed 7, Recycle 0 to 1: RMSD = 69.91 Å
# Model 2, Seed 7, Recycle 1 to 2: RMSD = 15.26 Å
# Model 2, Seed 7, Recycle 2 to 3: RMSD = 4.87 Å
# Convergence detected: RMSD = 4.87 Å. Copying files.
# Processing Model 5, Seed 6: Found 13 PDB files.
# Model 5, Seed 6, Recycle 0 to 1: RMSD = 65.94 Å
# Model 5, Seed 6, Recycle 1 to 2: RMSD = 9.76 Å
# Convergence detected: RMSD = 9.76 Å. Copying files.
# Processing Model 4, Seed 0: Found 13 PDB files.
# Model 4, Seed 0, Recycle 0 to 1: RMSD = 61.89 Å
# Model 4, Seed 0, Recycle 1 to 2: RMSD = 53.39 Å
# Model 4, Seed 0, Recycle 2 to 3: RMSD = 59.27 Å
# Model 4, Seed 0, Recycle 3 to 4: RMSD = 55.25 Å
# Model 4, Seed 0, Recycle 4 to 5: RMSD = 65.10 Å
# Model 4, Seed 0, Recycle 5 to 6: RMSD = 64.00 Å
# Model 4, Seed 0, Recycle 6 to 7: RMSD = 63.48 Å
# Model 4, Seed 0, Recycle 7 to 8: RMSD = 55.71 Å
# Model 4, Seed 0, Recycle 8 to 9: RMSD = 59.91 Å
# Model 4, Seed 0, Recycle 9 to 10: RMSD = 63.47 Å
# Model 4, Seed 0, Recycle 10 to 11: RMSD = 55.25 Å
# Model 4, Seed 0, Recycle 11 to 12: RMSD = 61.60 Å
# Processing Model 1, Seed 5: Found 13 PDB files.
# Model 1, Seed 5, Recycle 0 to 1: RMSD = 42.55 Å
# Model 1, Seed 5, Recycle 1 to 2: RMSD = 16.12 Å
# Model 1, Seed 5, Recycle 2 to 3: RMSD = 23.07 Å
# Model 1, Seed 5, Recycle 3 to 4: RMSD = 46.05 Å
# Model 1, Seed 5, Recycle 4 to 5: RMSD = 41.53 Å
# Model 1, Seed 5, Recycle 5 to 6: RMSD = 12.07 Å
# Model 1, Seed 5, Recycle 6 to 7: RMSD = 9.69 Å
# Convergence detected: RMSD = 9.69 Å. Copying files.
# Processing Model 2, Seed 4: Found 13 PDB files.
# Model 2, Seed 4, Recycle 0 to 1: RMSD = 50.94 Å
# Model 2, Seed 4, Recycle 1 to 2: RMSD = 11.61 Å
# Model 2, Seed 4, Recycle 2 to 3: RMSD = 4.01 Å
# Convergence detected: RMSD = 4.01 Å. Copying files.
# Processing Model 1, Seed 6: Found 13 PDB files.
# Model 1, Seed 6, Recycle 0 to 1: RMSD = 47.46 Å
# Model 1, Seed 6, Recycle 1 to 2: RMSD = 18.61 Å
# Model 1, Seed 6, Recycle 2 to 3: RMSD = 5.50 Å
# Convergence detected: RMSD = 5.50 Å. Copying files.
# Processing Model 2, Seed 8: Found 13 PDB files.
# Model 2, Seed 8, Recycle 0 to 1: RMSD = 55.71 Å
# Model 2, Seed 8, Recycle 1 to 2: RMSD = 15.32 Å
# Model 2, Seed 8, Recycle 2 to 3: RMSD = 13.18 Å
# Model 2, Seed 8, Recycle 3 to 4: RMSD = 48.65 Å
# Model 2, Seed 8, Recycle 4 to 5: RMSD = 20.67 Å
# Model 2, Seed 8, Recycle 5 to 6: RMSD = 16.01 Å
# Model 2, Seed 8, Recycle 6 to 7: RMSD = 14.21 Å
# Model 2, Seed 8, Recycle 7 to 8: RMSD = 16.30 Å
# Model 2, Seed 8, Recycle 8 to 9: RMSD = 12.06 Å
# Model 2, Seed 8, Recycle 9 to 10: RMSD = 11.73 Å
# Model 2, Seed 8, Recycle 10 to 11: RMSD = 8.41 Å
# Convergence detected: RMSD = 8.41 Å. Copying files.
# Processing Model 5, Seed 9: Found 13 PDB files.
# Model 5, Seed 9, Recycle 0 to 1: RMSD = 64.87 Å
# Model 5, Seed 9, Recycle 1 to 2: RMSD = 24.02 Å
# Model 5, Seed 9, Recycle 2 to 3: RMSD = 22.72 Å
# Model 5, Seed 9, Recycle 3 to 4: RMSD = 65.64 Å
# Model 5, Seed 9, Recycle 4 to 5: RMSD = 21.88 Å
# Model 5, Seed 9, Recycle 5 to 6: RMSD = 52.43 Å
# Model 5, Seed 9, Recycle 6 to 7: RMSD = 7.95 Å
# Convergence detected: RMSD = 7.95 Å. Copying files.
# Processing Model 3, Seed 5: Found 13 PDB files.
# Model 3, Seed 5, Recycle 0 to 1: RMSD = 56.01 Å
# Model 3, Seed 5, Recycle 1 to 2: RMSD = 57.12 Å
# Model 3, Seed 5, Recycle 2 to 3: RMSD = 56.05 Å
# Model 3, Seed 5, Recycle 3 to 4: RMSD = 51.52 Å
# Model 3, Seed 5, Recycle 4 to 5: RMSD = 55.20 Å
# Model 3, Seed 5, Recycle 5 to 6: RMSD = 65.76 Å
# Model 3, Seed 5, Recycle 6 to 7: RMSD = 62.62 Å
# Model 3, Seed 5, Recycle 7 to 8: RMSD = 57.41 Å
# Model 3, Seed 5, Recycle 8 to 9: RMSD = 56.95 Å
# Model 3, Seed 5, Recycle 9 to 10: RMSD = 60.94 Å
# Model 3, Seed 5, Recycle 10 to 11: RMSD = 56.59 Å
# Model 3, Seed 5, Recycle 11 to 12: RMSD = 59.33 Å
# Processing Model 1, Seed 2: Found 13 PDB files.
# Model 1, Seed 2, Recycle 0 to 1: RMSD = 56.99 Å
# Model 1, Seed 2, Recycle 1 to 2: RMSD = 24.29 Å
# Model 1, Seed 2, Recycle 2 to 3: RMSD = 23.23 Å
# Model 1, Seed 2, Recycle 3 to 4: RMSD = 34.38 Å
# Model 1, Seed 2, Recycle 4 to 5: RMSD = 22.33 Å
# Model 1, Seed 2, Recycle 5 to 6: RMSD = 58.04 Å
# Model 1, Seed 2, Recycle 6 to 7: RMSD = 10.14 Å
# Model 1, Seed 2, Recycle 7 to 8: RMSD = 20.51 Å
# Model 1, Seed 2, Recycle 8 to 9: RMSD = 22.93 Å
# Model 1, Seed 2, Recycle 9 to 10: RMSD = 43.01 Å
# Model 1, Seed 2, Recycle 10 to 11: RMSD = 6.72 Å
# Convergence detected: RMSD = 6.72 Å. Copying files.
# Processing Model 5, Seed 3: Found 13 PDB files.
# Model 5, Seed 3, Recycle 0 to 1: RMSD = 60.37 Å
# Model 5, Seed 3, Recycle 1 to 2: RMSD = 25.62 Å
# Model 5, Seed 3, Recycle 2 to 3: RMSD = 25.24 Å
# Model 5, Seed 3, Recycle 3 to 4: RMSD = 80.02 Å
# Model 5, Seed 3, Recycle 4 to 5: RMSD = 34.17 Å
# Model 5, Seed 3, Recycle 5 to 6: RMSD = 16.82 Å
# Model 5, Seed 3, Recycle 6 to 7: RMSD = 26.60 Å
# Model 5, Seed 3, Recycle 7 to 8: RMSD = 15.25 Å
# Model 5, Seed 3, Recycle 8 to 9: RMSD = 28.33 Å
# Model 5, Seed 3, Recycle 9 to 10: RMSD = 7.87 Å
# Convergence detected: RMSD = 7.87 Å. Copying files.
# Processing Model 4, Seed 5: Found 13 PDB files.
# Model 4, Seed 5, Recycle 0 to 1: RMSD = 68.02 Å
# Model 4, Seed 5, Recycle 1 to 2: RMSD = 61.03 Å
# Model 4, Seed 5, Recycle 2 to 3: RMSD = 51.97 Å
# Model 4, Seed 5, Recycle 3 to 4: RMSD = 53.22 Å
# Model 4, Seed 5, Recycle 4 to 5: RMSD = 63.90 Å
# Model 4, Seed 5, Recycle 5 to 6: RMSD = 62.89 Å
# Model 4, Seed 5, Recycle 6 to 7: RMSD = 65.24 Å
# Model 4, Seed 5, Recycle 7 to 8: RMSD = 55.56 Å
# Model 4, Seed 5, Recycle 8 to 9: RMSD = 58.31 Å
# Model 4, Seed 5, Recycle 9 to 10: RMSD = 62.44 Å
# Model 4, Seed 5, Recycle 10 to 11: RMSD = 59.31 Å
# Model 4, Seed 5, Recycle 11 to 12: RMSD = 61.07 Å
# Processing Model 4, Seed 7: Found 13 PDB files.
# Model 4, Seed 7, Recycle 0 to 1: RMSD = 64.25 Å
# Model 4, Seed 7, Recycle 1 to 2: RMSD = 62.27 Å
# Model 4, Seed 7, Recycle 2 to 3: RMSD = 51.51 Å
# Model 4, Seed 7, Recycle 3 to 4: RMSD = 54.36 Å
# Model 4, Seed 7, Recycle 4 to 5: RMSD = 70.26 Å
# Model 4, Seed 7, Recycle 5 to 6: RMSD = 54.08 Å
# Model 4, Seed 7, Recycle 6 to 7: RMSD = 56.28 Å
# Model 4, Seed 7, Recycle 7 to 8: RMSD = 66.02 Å
# Model 4, Seed 7, Recycle 8 to 9: RMSD = 66.05 Å
# Model 4, Seed 7, Recycle 9 to 10: RMSD = 42.58 Å
# Model 4, Seed 7, Recycle 10 to 11: RMSD = 64.07 Å
# Model 4, Seed 7, Recycle 11 to 12: RMSD = 60.26 Å
# Processing Model 5, Seed 1: Found 13 PDB files.
# Model 5, Seed 1, Recycle 0 to 1: RMSD = 65.66 Å
# Model 5, Seed 1, Recycle 1 to 2: RMSD = 17.84 Å
# Model 5, Seed 1, Recycle 2 to 3: RMSD = 18.43 Å
# Model 5, Seed 1, Recycle 3 to 4: RMSD = 62.90 Å
# Model 5, Seed 1, Recycle 4 to 5: RMSD = 38.10 Å
# Model 5, Seed 1, Recycle 5 to 6: RMSD = 26.24 Å
# Model 5, Seed 1, Recycle 6 to 7: RMSD = 31.09 Å
# Model 5, Seed 1, Recycle 7 to 8: RMSD = 21.75 Å
# Model 5, Seed 1, Recycle 8 to 9: RMSD = 27.67 Å
# Model 5, Seed 1, Recycle 9 to 10: RMSD = 4.68 Å
# Convergence detected: RMSD = 4.68 Å. Copying files.
# Processing Model 2, Seed 2: Found 13 PDB files.
# Model 2, Seed 2, Recycle 0 to 1: RMSD = 64.97 Å
# Model 2, Seed 2, Recycle 1 to 2: RMSD = 7.54 Å
# Convergence detected: RMSD = 7.54 Å. Copying files.
# Processing Model 1, Seed 0: Found 13 PDB files.
# Model 1, Seed 0, Recycle 0 to 1: RMSD = 45.00 Å
# Model 1, Seed 0, Recycle 1 to 2: RMSD = 26.27 Å
# Model 1, Seed 0, Recycle 2 to 3: RMSD = 12.43 Å
# Model 1, Seed 0, Recycle 3 to 4: RMSD = 42.32 Å
# Model 1, Seed 0, Recycle 4 to 5: RMSD = 47.32 Å
# Model 1, Seed 0, Recycle 5 to 6: RMSD = 10.30 Å
# Model 1, Seed 0, Recycle 6 to 7: RMSD = 22.92 Å
# Model 1, Seed 0, Recycle 7 to 8: RMSD = 16.37 Å
# Model 1, Seed 0, Recycle 8 to 9: RMSD = 10.25 Å
# Model 1, Seed 0, Recycle 9 to 10: RMSD = 13.22 Å
# Model 1, Seed 0, Recycle 10 to 11: RMSD = 13.92 Å
# Model 1, Seed 0, Recycle 11 to 12: RMSD = 19.09 Å
# Processing Model 1, Seed 8: Found 13 PDB files.
# Model 1, Seed 8, Recycle 0 to 1: RMSD = 61.20 Å
# Model 1, Seed 8, Recycle 1 to 2: RMSD = 7.37 Å
# Convergence detected: RMSD = 7.37 Å. Copying files.
# Processing Model 4, Seed 2: Found 13 PDB files.
# Model 4, Seed 2, Recycle 0 to 1: RMSD = 54.68 Å
# Model 4, Seed 2, Recycle 1 to 2: RMSD = 50.38 Å
# Model 4, Seed 2, Recycle 2 to 3: RMSD = 59.48 Å
# Model 4, Seed 2, Recycle 3 to 4: RMSD = 62.10 Å
# Model 4, Seed 2, Recycle 4 to 5: RMSD = 70.45 Å
# Model 4, Seed 2, Recycle 5 to 6: RMSD = 66.13 Å
# Model 4, Seed 2, Recycle 6 to 7: RMSD = 54.86 Å
# Model 4, Seed 2, Recycle 7 to 8: RMSD = 63.01 Å
# Model 4, Seed 2, Recycle 8 to 9: RMSD = 61.22 Å
# Model 4, Seed 2, Recycle 9 to 10: RMSD = 59.45 Å
# Model 4, Seed 2, Recycle 10 to 11: RMSD = 52.10 Å
# Model 4, Seed 2, Recycle 11 to 12: RMSD = 55.38 Å
# Processing Model 5, Seed 4: Found 13 PDB files.
# Model 5, Seed 4, Recycle 0 to 1: RMSD = 71.53 Å
# Model 5, Seed 4, Recycle 1 to 2: RMSD = 27.17 Å
# Model 5, Seed 4, Recycle 2 to 3: RMSD = 3.75 Å
# Convergence detected: RMSD = 3.75 Å. Copying files.
# Processing Model 3, Seed 3: Found 13 PDB files.
# Model 3, Seed 3, Recycle 0 to 1: RMSD = 56.19 Å
# Model 3, Seed 3, Recycle 1 to 2: RMSD = 60.81 Å
# Model 3, Seed 3, Recycle 2 to 3: RMSD = 51.64 Å
# Model 3, Seed 3, Recycle 3 to 4: RMSD = 43.19 Å
# Model 3, Seed 3, Recycle 4 to 5: RMSD = 25.78 Å
# Model 3, Seed 3, Recycle 5 to 6: RMSD = 60.56 Å
# Model 3, Seed 3, Recycle 6 to 7: RMSD = 63.54 Å
# Model 3, Seed 3, Recycle 7 to 8: RMSD = 62.72 Å
# Model 3, Seed 3, Recycle 8 to 9: RMSD = 57.13 Å
# Model 3, Seed 3, Recycle 9 to 10: RMSD = 61.24 Å
# Model 3, Seed 3, Recycle 10 to 11: RMSD = 58.64 Å
# Model 3, Seed 3, Recycle 11 to 12: RMSD = 50.86 Å
# Processing Model 2, Seed 3: Found 13 PDB files.
# Model 2, Seed 3, Recycle 0 to 1: RMSD = 59.67 Å
# Model 2, Seed 3, Recycle 1 to 2: RMSD = 8.74 Å
# Convergence detected: RMSD = 8.74 Å. Copying files.
# Processing Model 3, Seed 2: Found 13 PDB files.
# Model 3, Seed 2, Recycle 0 to 1: RMSD = 56.71 Å
# Model 3, Seed 2, Recycle 1 to 2: RMSD = 49.94 Å
# Model 3, Seed 2, Recycle 2 to 3: RMSD = 62.18 Å
# Model 3, Seed 2, Recycle 3 to 4: RMSD = 55.15 Å
# Model 3, Seed 2, Recycle 4 to 5: RMSD = 67.50 Å
# Model 3, Seed 2, Recycle 5 to 6: RMSD = 60.64 Å
# Model 3, Seed 2, Recycle 6 to 7: RMSD = 48.51 Å
# Model 3, Seed 2, Recycle 7 to 8: RMSD = 62.52 Å
# Model 3, Seed 2, Recycle 8 to 9: RMSD = 59.80 Å
# Model 3, Seed 2, Recycle 9 to 10: RMSD = 52.40 Å
# Model 3, Seed 2, Recycle 10 to 11: RMSD = 58.95 Å
# Model 3, Seed 2, Recycle 11 to 12: RMSD = 62.42 Å
# Processing Model 4, Seed 3: Found 13 PDB files.
# Model 4, Seed 3, Recycle 0 to 1: RMSD = 53.15 Å
# Model 4, Seed 3, Recycle 1 to 2: RMSD = 56.15 Å
# Model 4, Seed 3, Recycle 2 to 3: RMSD = 65.27 Å
# Model 4, Seed 3, Recycle 3 to 4: RMSD = 61.06 Å
# Model 4, Seed 3, Recycle 4 to 5: RMSD = 68.18 Å
# Model 4, Seed 3, Recycle 5 to 6: RMSD = 67.88 Å
# Model 4, Seed 3, Recycle 6 to 7: RMSD = 56.56 Å
# Model 4, Seed 3, Recycle 7 to 8: RMSD = 69.46 Å
# Model 4, Seed 3, Recycle 8 to 9: RMSD = 64.60 Å
# Model 4, Seed 3, Recycle 9 to 10: RMSD = 60.03 Å
# Model 4, Seed 3, Recycle 10 to 11: RMSD = 70.15 Å
# Model 4, Seed 3, Recycle 11 to 12: RMSD = 58.86 Å
# Processing Model 5, Seed 5: Found 13 PDB files.
# Model 5, Seed 5, Recycle 0 to 1: RMSD = 63.98 Å
# Model 5, Seed 5, Recycle 1 to 2: RMSD = 28.74 Å
# Model 5, Seed 5, Recycle 2 to 3: RMSD = 17.20 Å
# Model 5, Seed 5, Recycle 3 to 4: RMSD = 65.99 Å
# Model 5, Seed 5, Recycle 4 to 5: RMSD = 23.05 Å
# Model 5, Seed 5, Recycle 5 to 6: RMSD = 33.31 Å
# Model 5, Seed 5, Recycle 6 to 7: RMSD = 39.63 Å
# Model 5, Seed 5, Recycle 7 to 8: RMSD = 13.15 Å
# Model 5, Seed 5, Recycle 8 to 9: RMSD = 29.26 Å
# Model 5, Seed 5, Recycle 9 to 10: RMSD = 33.64 Å
# Model 5, Seed 5, Recycle 10 to 11: RMSD = 21.89 Å
# Model 5, Seed 5, Recycle 11 to 12: RMSD = 54.71 Å
# Processing Model 1, Seed 9: Found 13 PDB files.
# Model 1, Seed 9, Recycle 0 to 1: RMSD = 55.67 Å
# Model 1, Seed 9, Recycle 1 to 2: RMSD = 32.92 Å
# Model 1, Seed 9, Recycle 2 to 3: RMSD = 23.03 Å
# Model 1, Seed 9, Recycle 3 to 4: RMSD = 54.26 Å
# Model 1, Seed 9, Recycle 4 to 5: RMSD = 18.70 Å
# Model 1, Seed 9, Recycle 5 to 6: RMSD = 38.43 Å
# Model 1, Seed 9, Recycle 6 to 7: RMSD = 27.98 Å
# Model 1, Seed 9, Recycle 7 to 8: RMSD = 18.67 Å
# Model 1, Seed 9, Recycle 8 to 9: RMSD = 22.39 Å
# Model 1, Seed 9, Recycle 9 to 10: RMSD = 4.97 Å
# Convergence detected: RMSD = 4.97 Å. Copying files.
# Processing Model 1, Seed 1: Found 13 PDB files.
# Model 1, Seed 1, Recycle 0 to 1: RMSD = 47.33 Å
# Model 1, Seed 1, Recycle 1 to 2: RMSD = 22.95 Å
# Model 1, Seed 1, Recycle 2 to 3: RMSD = 12.93 Å
# Model 1, Seed 1, Recycle 3 to 4: RMSD = 47.96 Å
# Model 1, Seed 1, Recycle 4 to 5: RMSD = 51.59 Å
# Model 1, Seed 1, Recycle 5 to 6: RMSD = 11.76 Å
# Model 1, Seed 1, Recycle 6 to 7: RMSD = 16.50 Å
# Model 1, Seed 1, Recycle 7 to 8: RMSD = 6.71 Å
# Convergence detected: RMSD = 6.71 Å. Copying files.
